# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import pandas

# %%
from pandas import read_csv
url = "pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(url, names = names)

# %%
data.shape
# Out:
# (777, 9)

# %%
data.dtypes
# Out:
# preg      object
# plas     float64
# pres     float64
# skin     float64
# test     float64
# mass     float64
# pedi     float64
# age      float64
# class    float64
# dtype: object

# %%
data.describe()
# Out:
#              plas        pres        skin        test        mass        pedi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean   120.894531   69.105469   20.536458   79.799479   31.992578    0.471876
# std     31.972618   19.355807   15.952218  115.244002    7.884160    0.331329
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.078000
# 25%     99.000000   62.000000    0.000000    0.000000   27.300000    0.243750
# 50%    117.000000   72.000000   23.000000   30.500000   32.000000    0.372500
# 75%    140.250000   80.000000   32.000000  127.250000   36.600000    0.626250
# max    199.000000  122.000000   99.000000  846.000000   67.100000    2.420000
#
#               age       class
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
data.head(2)
# Out:
#                                                 preg  plas  pres  skin  test  \
# 0                      # 1. Number of times pregnant   NaN   NaN   NaN   NaN
# 1  # 2. Plasma glucose concentration a 2 hours in...   NaN   NaN   NaN   NaN
#
#    mass  pedi  age  class
# 0   NaN   NaN  NaN    NaN
# 1   NaN   NaN  NaN    NaN

# %%
data.groupby('class').size()
# Out:
# class
# 0.0    500
# 1.0    268
# dtype: int64

# %%
print(data.corr(method = 'pearson'))
# Out:
#            plas      pres      skin      test      mass      pedi       age  \
# plas   1.000000  0.152590  0.057328  0.331357  0.221071  0.137337  0.263514
# pres   0.152590  1.000000  0.207371  0.088933  0.281805  0.041265  0.239528
# skin   0.057328  0.207371  1.000000  0.436783  0.392573  0.183928 -0.113970
# test   0.331357  0.088933  0.436783  1.000000  0.197859  0.185071 -0.042163
# mass   0.221071  0.281805  0.392573  0.197859  1.000000  0.140647  0.036242
# pedi   0.137337  0.041265  0.183928  0.185071  0.140647  1.000000  0.033561
# age    0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561  1.000000
# class  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844  0.238356
#
#           class
# plas   0.466581
# pres   0.065068
# skin   0.074752
# test   0.130548
# mass   0.292695
# pedi   0.173844
# age    0.238356
# class  1.000000

# %%
data.skew()
# Out:
# plas     0.173754
# pres    -1.843608
# skin     0.109372
# test     2.272251
# mass    -0.428982
# pedi     1.919911
# age      1.129597
# class    0.635017
# dtype: float64

# %%
data.hist()
plt.show()

# %%
data.plot(kind = 'density', subplots = True, layout = (3, 3), sharex = False)
plt.show()

# %%
data.plot(kind = 'box', subplots = True, layout = (3,3), sharex = False, sharey = False)
# Out:
# plas        AxesSubplot(0.125,0.657941;0.227941x0.222059)
# pres     AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# skin     AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# test        AxesSubplot(0.125,0.391471;0.227941x0.222059)
# mass     AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# pedi     AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# age            AxesSubplot(0.125,0.125;0.227941x0.222059)
# class       AxesSubplot(0.398529,0.125;0.227941x0.222059)
# dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(data.corr('pearson'), vmin = -1, vmax = 1)
fig.colorbar(cax)

ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(data)
plt.show()
